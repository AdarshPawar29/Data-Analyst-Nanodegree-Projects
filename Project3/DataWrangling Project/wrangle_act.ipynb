# %% [markdown]
# ## Gathering Data

# %% [markdown]
# I imported all the required packages:-

# %%
import pandas as pd
import numpy as np
import requests as req
import tweepy
import json
import matplotlib

# %% [markdown]
# ### 1. df_enhanced dataset

# %%
df_enhanced = pd.read_csv('twitter-archive-enhanced.csv')

# %% [markdown]
# Downloaded from web.

# %%
df_enhanced.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
df_enhanced.tail()
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 2351  666049248165822465                    NaN                  NaN
# 2352  666044226329800704                    NaN                  NaN
# 2353  666033412701032449                    NaN                  NaN
# 2354  666029285002620928                    NaN                  NaN
# 2355  666020888022790149                    NaN                  NaN
#
#                       timestamp  \
# 2351  2015-11-16 00:24:50 +0000
# 2352  2015-11-16 00:04:52 +0000
# 2353  2015-11-15 23:21:54 +0000
# 2354  2015-11-15 23:05:30 +0000
# 2355  2015-11-15 22:32:08 +0000
#
#                                                  source  \
# 2351  <a href="http://twitter.com/download/iphone" r...
# 2352  <a href="http://twitter.com/download/iphone" r...
# 2353  <a href="http://twitter.com/download/iphone" r...
# 2354  <a href="http://twitter.com/download/iphone" r...
# 2355  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %% [markdown]
# ### 2. df_breed Dataset

# %%
r = req.get('https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv')

# %% [markdown]
# I took an overview of dataset type and separator used.

# %%
r.headers['content-type']
# Out:
# 'text/tab-separated-values; charset=utf-8'

# %% [markdown]
# A content path is saved into a variable called path which will be read in the file.

# %%
path = 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'

# %%
df_breed = pd.read_csv(path, sep = '\t')

# %%
df_breed.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %% [markdown]
# ### 3. df_tweets Dataset

# %%
consumer_key = "xxxxxxxxxxxxxxxxxxxxxxxxx"
consumer_secret = "xxxxxxxxxxxxxxxxxxxxxx"
access_token = "xxxxxxxxxxxxxxxxxxxxxxxxxxxxx"
access_secret = "xxxxxxxxxxxxxxxxxxxxxxxxxxxx"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth, wait_on_rate_limit=True)

# %% [markdown]
# Created a consumer key, secret, access token and secret for twitter api thourgh this link:-
# https://apps.twitter.com/app/new

# %% [markdown]
# Created 'id_list',it is the list of tweet ids.

# %%
id_list = df_enhanced['tweet_id']

# %%
id_list
# Out:
# 0       892420643555336193
# 1       892177421306343426
# 2       891815181378084864
# 3       891689557279858688
# 4       891327558926688256
# 5       891087950875897856
# 6       890971913173991426
# 7       890729181411237888
# 8       890609185150312448
# 9       890240255349198849
# 10      890006608113172480
# 11      889880896479866881
# 12      889665388333682689
# 13      889638837579907072
# 14      889531135344209921
# 15      889278841981685760
# 16      888917238123831296
# 17      888804989199671297
# 18      888554962724278272
# 19      888202515573088257
# 20      888078434458587136
# 21      887705289381826560
# 22      887517139158093824
# 23      887473957103951883
# 24      887343217045368832
# 25      887101392804085760
# 26      886983233522544640
# 27      886736880519319552
# 28      886680336477933568
# 29      886366144734445568
#                ...
# 2326    666411507551481857
# 2327    666407126856765440
# 2328    666396247373291520
# ...

# %% [markdown]
# I saved tweets in json to readable text file. And creating the exceptions list.

# %% [markdown]
# Source: https://stackoverflow.com/questions/34379168/how-to-save-the-tweets-in-json-to-txt-file-in-python-3-4

# %%
# a list for the exceptions
exceptions_list = []

# opening the file to write mode
with open('tweet_json.txt', 'w', encoding = 'utf-8') as f:
    for id_tweet in id_list: 
        try:
            tweet = api.get_status(id_tweet, tweet_mode= 'extended')
            json.dump(tweet._json, f)
# writing the content with new paragraphs
            f.write("\n")
        except Exception as e:
            exceptions_list.append(id_tweet)
# printing out the exception messages
            print(str(e))
# Out:
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 34, 'message': 'Sorry, that page does not exist.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]
# [{'code': 144, 'message': 'No status found with that ID.'}]

# %%
# Reading the json file
df_full_json = pd.read_json('tweet_json.txt', orient='records', lines = True)

# %%
# Checking the columns to find out which values we would like to extract.
df_full_json.columns
# Out:
# Index(['contributors', 'coordinates', 'created_at', 'display_text_range',
#        'entities', 'extended_entities', 'favorite_count', 'favorited',
#        'full_text', 'geo', 'id', 'id_str', 'in_reply_to_screen_name',
#        'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status',
#        'lang', 'place', 'possibly_sensitive', 'possibly_sensitive_appealable',
#        'quoted_status', 'quoted_status_id', 'quoted_status_id_str',
#        'retweet_count', 'retweeted', 'retweeted_status', 'source', 'truncated',
#        'user'],
#       dtype='object')

# %%
# We have the retweeted variable, and we have to know about it's status.
df_tweets = df_full_json[['id','favorite_count', 'retweet_count', 'retweeted']]

# %%
df_tweets.head()
# Out:
#                    id  favorite_count  retweet_count  retweeted
# 0  892420643555336193           39060           8676      False
# 1  892177421306343426           33457           6373      False
# 2  891815181378084864           25216           4233      False
# 3  891689557279858688           42431           8778      False
# 4  891327558926688256           40588           9558      False

# %%
df_tweets.tail()
# Out:
#                       id  favorite_count  retweet_count  retweeted
# 2341  666049248165822465             109             40      False
# 2342  666044226329800704             304            142      False
# 2343  666033412701032449             126             46      False
# 2344  666029285002620928             131             48      False
# 2345  666020888022790149            2524            519      False

# %% [markdown]
# ## Assesing Data

# %% [markdown]
# ### 1. df_tweets dataset

# %% [markdown]
# df_tweets dataset view.

# %%
df_tweets
# Out:
#                       id  favorite_count  retweet_count  retweeted
# 0     892420643555336193           39060           8676      False
# 1     892177421306343426           33457           6373      False
# 2     891815181378084864           25216           4233      False
# 3     891689557279858688           42431           8778      False
# 4     891327558926688256           40588           9558      False
# 5     891087950875897856           20357           3172      False
# 6     890971913173991426           11935           2113      False
# 7     890729181411237888           66028          19229      False
# 8     890609185150312448           27953           4331      False
# 9     890240255349198849           32165           7552      False
# 10    890006608113172480           30847           7458      False
# 11    889880896479866881           27976           5049      False
# 12    889665388333682689           48372          10238      False
# ...

# %% [markdown]
# I checked the retweets in the dataset by counting the retweeted values when it may True. But there are not any retweeted values.

# %%
len(df_tweets.query('retweeted == True'))
# Out:
# 0

# %% [markdown]
# Checking for any duplicate value by id

# %%
df_tweets[df_tweets['id'].duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [id, favorite_count, retweet_count, retweeted]
# Index: []

# %%
df_tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2346 entries, 0 to 2345
# Data columns (total 4 columns):
# id                2346 non-null int64
# favorite_count    2346 non-null int64
# retweet_count     2346 non-null int64
# retweeted         2346 non-null bool
# dtypes: bool(1), int64(3)
# memory usage: 75.6 KB

# %% [markdown]
# As I checked for redundancy and assessing, it seems that there is not anyone special problem in this data frame.

# %% [markdown]
# ### 2. df_enhanced dataset

# %% [markdown]
# I printed out the archive dataset after modification as a df_enhanced dataset.

# %%
df_enhanced
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0     892420643555336193                    NaN                  NaN
# 1     892177421306343426                    NaN                  NaN
# 2     891815181378084864                    NaN                  NaN
# 3     891689557279858688                    NaN                  NaN
# 4     891327558926688256                    NaN                  NaN
# 5     891087950875897856                    NaN                  NaN
# 6     890971913173991426                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 8     890609185150312448                    NaN                  NaN
# 9     890240255349198849                    NaN                  NaN
# 10    890006608113172480                    NaN                  NaN
# 11    889880896479866881                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# ...

# %%
# View rows where the value of 'name' is lowercase - indicates that it is not an actual name
df_enhanced.groupby('name')['name'].size()
# Out:
# name
# Abby             2
# Ace              1
# Acro             1
# Adele            1
# Aiden            1
# Aja              1
# Akumi            1
# Al               1
# Albert           2
# Albus            2
# Aldrick          1
# Alejandro        1
# Alexander        1
# Alexanderson     1
# Alf              1
# Alfie            5
# Alfy             1
# Alice            2
# Amber            1
# Ambrose          1
# Amy              1
# Amélie           1
# Anakin           2
# Andru            1
# Andy             1
# Angel            1
# Anna             1
# Anthony          1
# Antony           1
# Apollo           1
#                 ..
# Ziva             1
# Zoe              1
# Zoey             3
# Zooey            1
# Zuzu             1
# a               55
# actually         2
# all              1
# an               7
# by               1
# getting          2
# his              1
# incredibly       1
# infuriating      1
# just             4
# life             1
# ...

# %%
df_enhanced['name'].describe()
# Out:
# count     2356
# unique     957
# top       None
# freq       745
# Name: name, dtype: object

# %% [markdown]
# Cheking the null values and datatypes.

# %%
# View descriptive statistics of df_enhanced DataFrame
df_enhanced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %% [markdown]
# I ckecked if there are any values duplicated by their id.

# %%
df_enhanced[df_enhanced['tweet_id'].duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [tweet_id, in_reply_to_status_id, in_reply_to_user_id, timestamp, source, text, retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp, expanded_urls, rating_numerator, rating_denominator, name, doggo, floofer, pupper, puppo]
# Index: []

# %% [markdown]
# ### 3. df_breed dataset

# %%
# View first five descriptive statistics of df_breed DataFrame
df_breed.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %% [markdown]
# the datatypes of every variable.

# %%
# View descriptive statistics of df_breed DataFrame
df_breed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %% [markdown]
# Finding the null values, if it contain any.

# %%
nulls = df_breed.columns[df_breed.isnull().any()]
df_breed[nulls].isnull().sum()
# Out:
# Series([], dtype: float64)

# %% [markdown]
# ## Summary
#
#
# - We having 3 datasets in the place of 1 master dataset
#
# df_enhanced dataset:
#
# - unnecessary category columns:  doggo, floofer, pupper, puppo
# - Incorrect dog names
# - Sources difficult to read
#
#
# df_breed dataset:
#
# - unnecessary columns like info columns with some variable
# - so many parts of the same columns
#
#
# #### Quality:
#
# df_enhanced dataset:
#
# - the dog_stage is string datatype
# - unnecessary rating denominator column
# - rating numerator column header without scale
# - missing names in name column all most all in lowercase and incorrect: such, quite, a, an, the... - all are written with lower case letters
# - retweeted records: retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp
# - missing data in name and stages columns showing as 'None'
# - incorrect datatypes: timestamp is a string
# - in_reply_to_status_id, in_reply_to_user_id should be changed from scientific float to string
# - wrong rating numerators were extracted from the text column
#
# df_breed dataset:
#
# - dog breeds start with lower case letters
# - non-dog records in the dataset (eg.: shopping cart, box turtle...)
# - the p1, p2, p2 columns should be categorical datatypes
#
# df_tweets dataset:
#
# - so many unnecessary columns  like contributors, coordinates, created_at, display_text_range, full_text, geo, id_str, in_reply_to_screen_name, in_reply_to_status_id, in_reply_to_status_id_str etc.
# - there are only few important columns is used in dataset

# %% [markdown]
# ## Cleaning Process

# %% [markdown]
# ### 1. df_enhanced Dataset

# %% [markdown]
# #### Define:
# Retweeted records in the dataset: retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp

# %% [markdown]
# #### Code:
# I removed all the retweeted tweets, so I can analyze the true rating. I selected all the observations where the retweeted status was not null and remove the values. There are some unnecessary  variable which is also removed like  retweeted_status_id, retweeted_status_user_id, retweeted_status_timestamp columns.

# %% [markdown]
# The number of retweeted tweets from a df_enhanced data frame.

# %%
len(df_enhanced.query('retweeted_status_id != "NaN"'))
# Out:
# 181

# %% [markdown]
# a new data frame without the retweeted tweets.

# %%
df_enhanced = df_enhanced.query('retweeted_status_id == "NaN"')

# %% [markdown]
# #### Test:

# %% [markdown]
# Final check for retweeted to make sure about data frame.

# %%
len(df_enhanced.query('retweeted_status_id != "NaN"'))
# Out:
# 0

# %% [markdown]
# After checking, the unnecessary empty columns are removed from a data frame.

# %%
df_enhanced = df_enhanced.drop(['retweeted_status_id', 'retweeted_status_user_id', 'retweeted_status_timestamp'], axis=1)

# %% [markdown]
# #### Define:
# rating denominator column is removed and rating column variable without scale.
#
# #### Code:
#
# the rating denominator column is removed and a scale to the numerator column in the title is added.

# %%
df_enhanced = df_enhanced.drop('rating_denominator', axis=1)

# %%
df_enhanced = df_enhanced.rename(index=str, columns={"rating_numerator": "rating_10_scale"})

# %% [markdown]
# #### Test:

# %%
df_enhanced.head(3)
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# 2  This is Archie. He is a rare Norwegian Pouncin...
#
#                                        expanded_urls  rating_10_scale  \
# ...

# %% [markdown]
# #### Define:
# There are incorrect numerators in the rating_numerator column it have wrong datatype (decimals are shown as integers).
#
# #### Code:
# The datatype of the column is changed and extracted the right numerators of the text column with regex.
# I iterated through the df_enhanced database and changed the wrong values with the extracted data on each corresponding row.

# %% [markdown]
# Cleaning the rating_numerator columns, extract the right values from the text column.

# %%
# setting the rating_10_scale column to float

df_enhanced['rating_10_scale'] = df_enhanced['rating_10_scale'].astype('float')

# %%
df_enhanced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2175 entries, 0 to 2355
# Data columns (total 13 columns):
# tweet_id                 2175 non-null int64
# in_reply_to_status_id    78 non-null float64
# in_reply_to_user_id      78 non-null float64
# timestamp                2175 non-null object
# source                   2175 non-null object
# text                     2175 non-null object
# expanded_urls            2117 non-null object
# rating_10_scale          2175 non-null float64
# name                     2175 non-null object
# doggo                    2175 non-null object
# floofer                  2175 non-null object
# pupper                   2175 non-null object
# puppo                    2175 non-null object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 237.9+ KB

# %%
# save values into dataframe where text contains decimals
df_bad_numerator = df_enhanced[df_enhanced.text.str.contains(r"(\d+\.\d*\/\d+)")]

# creating a list to append the extracted values
numerator = []

for item in  df_bad_numerator['text']:
    splitted = item.split('/')
    numerator.append(splitted[0].split()[-1])
print(numerator)
# Out:
# ['13.5', '9.75', '11.27', '9.5', '11.26']
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.

# %%
# a list of the corresponding tweet_id_list.
tweet_id_list = df_bad_numerator['tweet_id'].tolist()

for i in range(len(tweet_id_list)):
    # change the numerator in the oroginal dataframe
    df_enhanced.loc[(df_enhanced['tweet_id'] == tweet_id_list[i]), ['rating_10_scale']] = numerator[i]
    # test: print out the changed values in the original daraframe
    print(df_enhanced.loc[(df_enhanced['tweet_id'] == tweet_id_list[i]), ['rating_10_scale']])
# Out:
#    rating_10_scale
# 45            13.5
#     rating_10_scale
# 695            9.75
#     rating_10_scale
# 763           11.27
#      rating_10_scale
# 1689             9.5
#      rating_10_scale
# 1712           11.26

# %%
# view of df_enhanced datafream.
df_enhanced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2175 entries, 0 to 2355
# Data columns (total 13 columns):
# tweet_id                 2175 non-null int64
# in_reply_to_status_id    78 non-null float64
# in_reply_to_user_id      78 non-null float64
# timestamp                2175 non-null object
# source                   2175 non-null object
# text                     2175 non-null object
# expanded_urls            2117 non-null object
# rating_10_scale          2175 non-null object
# name                     2175 non-null object
# doggo                    2175 non-null object
# floofer                  2175 non-null object
# pupper                   2175 non-null object
# puppo                    2175 non-null object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 237.9+ KB

# %% [markdown]
# #### Define:
#
# There are still some more issues with the name column. It has missing values and incorrect value, missing values have to be marked none.
#
# #### Code:
#
# The valid dag name starts from uppercase letter and rest of the name which is un valid is start from a lowercase letter. The dag name can be extracted from the name columns to replace the none value where the missing value and invalid names.
#
# There are some cases and expressions where the dag names occur in the column in this circumstances:
#     - ... named [Dog Name]
#     - meet [Dog Name]
#     - .. name is [Dog Name]
#     - This is [Dog Name]
#     - Say hello to [Dog Name]
#     - Meet [Dog Name]
#     - Here we have [Dog Name]
#     - Here is [Dog Name]
#
# After that, I will try to match this through the text columns and get the name from those columns based on expressions.

# %%
import re

# Creating two lists: one for the names we can extract and one for the new names
names_clean = []
missing_names = []

# Creating a lit of the texts
text_list = df_enhanced['text'].values.tolist()

# Creating a regex pattern
pattern = re.compile('([A-Z].*)')

# Iterating thourgh the text list and check if the content and pattern correspond to some of the extressions
for text in df_enhanced['text']:
    
    if text.__contains__('This is') and pattern.fullmatch(text.split()[text.split().index("is")+1]):
        names_clean.append(text.split(" ")[2].strip('.').strip(','))
    elif text.startswith("Meet") and pattern.fullmatch(text.split(" ")[1]):
        names_clean.append(text.split(" ")[1].strip('.').strip(','))
    elif text.startswith("Here we have") and pattern.fullmatch(text.split(" ", 3)[3]):
        names_clean.append(text.split(" ")[3].strip('.').strip(','))
    elif text.split(" ").__contains__("named") and pattern.fullmatch(text.split()[text.split().index("named")+1]):
        names_clean.append(text.split()[text.split().index("named")+1].strip('.').strip(','))
    elif text.__contains__("name is") and pattern.fullmatch(text.split()[text.split().index("is")+1]):
        names_clean.append(text.split()[text.split().index("is")+1].strip('.').strip(','))
    elif text.__contains__("Say hello to") and pattern.fullmatch(text.split()[text.split().index("to")+1]):
        names_clean.append(text.split(" ")[3].strip('.').strip(','))
    else:
        names_clean.append("NaN")
        missing_names.append(text)

# %% [markdown]
# #### Test:

# %%
len(names_clean)
# Out:
# 2175

# %% [markdown]
# Checking the number of the missing names.

# %%
len(missing_names)
# Out:
# 755

# %% [markdown]
# Looking at the content to see if we found any dog names to extract.

# %%
missing_names
# Out:
# ["Here we have a majestic great white breaching off South Africa's coast. Absolutely h*ckin breathtaking. 13/10 (IG: tucker_marlo) #BarkWeek https://t.co/kQ04fDDRmh",
#  "When you watch your owner call another dog a good boy but then they turn back to you and say you're a great boy. 13/10 https://t.co/v0nONBcwxq",
#  "Here's a puppo that seems to be on the fence about something haha no but seriously someone help her. 13/10 https://t.co/BxvuXk0UCm",
#  "I've yet to rate a Venezuelan Hover Wiener. This is such an honor. 14/10 paw-inspiring af (IG: roxy.thedoxy) https://t.co/20VrLAA8ba",
#  'You may not have known you needed to see this today. 13/10 please enjoy (IG: emmylouroo) https://t.co/WZqNqygEyV',
#  'This... is a Jubilant Antarctic House Bear. We only rate dogs. Please only send dogs. Thank you... 12/10 would suffocate in floof https://t.co/4Ad1jzJSdp',
#  '@NonWhiteHat @MayhewMayhem omg hello tanner you are a scary good boy 12/10 would pet with extreme caution',
# ...

# %% [markdown]
# After checking, storing the new names into the dataframe.

# %%
df_enhanced['dog_name'] = names_clean

# %%
len(df_enhanced['dog_name'])
# Out:
# 2175

# %% [markdown]
# I compared the original names column with the new, cleaned one.

# %%
df_enhanced[['name']].groupby(['name'])['name'].size()
# Out:
# name
# Abby             2
# Ace              1
# Acro             1
# Adele            1
# Aiden            1
# Aja              1
# Akumi            1
# Al               1
# Albert           2
# Albus            2
# Aldrick          1
# Alejandro        1
# Alexander        1
# Alexanderson     1
# Alf              1
# Alfie            4
# Alfy             1
# Alice            2
# Amber            1
# Ambrose          1
# Amy              1
# Amélie           1
# Anakin           1
# Andru            1
# Andy             1
# Angel            1
# Anna             1
# Anthony          1
# Antony           1
# Apollo           1
#                 ..
# Ziva             1
# Zoe              1
# Zoey             3
# Zooey            1
# Zuzu             1
# a               55
# actually         2
# all              1
# an               6
# by               1
# getting          2
# his              1
# incredibly       1
# infuriating      1
# just             3
# life             1
# ...

# %% [markdown]
# Looking at the new name (dog_name).

# %%
df_enhanced[['dog_name']].groupby(['dog_name'])['dog_name'].size()
# Out:
# dog_name
# Abby            2
# Ace             1
# Acro            1
# Adele           1
# Aiden           1
# Aja             1
# Akumi           1
# Al              1
# Albert          2
# Albus           2
# Aldrick         1
# Alejandro       1
# Alexander       1
# Alexanderson    1
# Alf             1
# Alfie           4
# Alfonso         1
# Alfredo         1
# Alfy            1
# Alice           2
# Alphred         1
# Amber           1
# Ambrose         1
# Amy             1
# Amélie          1
# Anakin          1
# Andru           1
# Andy            1
# Angel           1
# Anna            1
#                ..
# Watson          2
# Wesley          1
# Wiggles         1
# Willem          1
# William         1
# Willie          1
# Willow          1
# Willy           1
# Wilson          3
# Winifred        1
# Winnie          4
# Winston         8
# Wishes          1
# Wyatt           3
# Wylie           1
# Yoda            1
# Yogi            2
# Yukon           1
# ...

# %% [markdown]
# As we can see at the bottom of the list, there are still some incorrect values with lower case letter. I replace them with NaN.

# %%
df_enhanced['dog_name'] = df_enhanced['dog_name'].replace(to_replace = r'^([a-z])', value = np.nan, regex = True)

# %% [markdown]
# Final result.

# %%
df_enhanced[['dog_name']].groupby(['dog_name'])['dog_name'].size()
# Out:
# dog_name
# Abby            2
# Ace             1
# Acro            1
# Adele           1
# Aiden           1
# Aja             1
# Akumi           1
# Al              1
# Albert          2
# Albus           2
# Aldrick         1
# Alejandro       1
# Alexander       1
# Alexanderson    1
# Alf             1
# Alfie           4
# Alfonso         1
# Alfredo         1
# Alfy            1
# Alice           2
# Alphred         1
# Amber           1
# Ambrose         1
# Amy             1
# Amélie          1
# Anakin          1
# Andru           1
# Andy            1
# Angel           1
# Anna            1
#                ..
# Wallace         3
# Wally           2
# Walter          3
# Watson          2
# Wesley          1
# Wiggles         1
# Willem          1
# William         1
# Willie          1
# Willow          1
# Willy           1
# Wilson          3
# Winifred        1
# Winnie          4
# Winston         8
# Wishes          1
# Wyatt           3
# Wylie           1
# ...

# %% [markdown]
# Looking at the missing values.

# %%
df_enhanced[df_enhanced['dog_name'] == "NaN"]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 5     891087950875897856                    NaN                  NaN
# 7     890729181411237888                    NaN                  NaN
# 12    889665388333682689                    NaN                  NaN
# 22    887517139158093824                    NaN                  NaN
# 24    887343217045368832                    NaN                  NaN
# 25    887101392804085760                    NaN                  NaN
# 30    886267009285017600           8.862664e+17         2.281182e+09
# 37    885167619883638784                    NaN                  NaN
# 41    884441805382717440                    NaN                  NaN
# 42    884247878851493888                    NaN                  NaN
# 47    883117836046086144                    NaN                  NaN
# 55    881633300179243008           8.816070e+17         4.738443e+07
# 56    881536004380872706                    NaN                  NaN
# ...

# %% [markdown]
# I dropped the name column.

# %%
df_enhanced = df_enhanced.drop('name', axis = 1)

# %% [markdown]
# Moving the dog_name column forward, to the place of the old name column, using pop and ix.
#
# Source: https://stackoverflow.com/questions/25122099/move-column-by-name-to-front-of-table-in-pandas

# %%
cols = list(df_enhanced)

cols.insert(8, cols.pop(cols.index('dog_name')))

# %%
cols
# Out:
# ['tweet_id',
#  'in_reply_to_status_id',
#  'in_reply_to_user_id',
#  'timestamp',
#  'source',
#  'text',
#  'expanded_urls',
#  'rating_10_scale',
#  'dog_name',
#  'doggo',
#  'floofer',
#  'pupper',
#  'puppo']

# %%
df_enhanced = df_enhanced.ix[:, cols]
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
df_enhanced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2175 entries, 0 to 2355
# Data columns (total 13 columns):
# tweet_id                 2175 non-null int64
# in_reply_to_status_id    78 non-null float64
# in_reply_to_user_id      78 non-null float64
# timestamp                2175 non-null object
# source                   2175 non-null object
# text                     2175 non-null object
# expanded_urls            2117 non-null object
# rating_10_scale          2175 non-null object
# dog_name                 2172 non-null object
# doggo                    2175 non-null object
# floofer                  2175 non-null object
# pupper                   2175 non-null object
# puppo                    2175 non-null object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 237.9+ KB

# %% [markdown]
# #### Define:
# Incorrect datatypes (timestamp, retweetd_status_id, retweeted_status_user_id, retweeted_status_timestamp)
#
#
# #### Code:
# Changing the incorrect data types:
# - timestamp
# - retweeted_status_id
# - retweeted_status_user_id
# - retweeted_status_timestamp

# %%
df_enhanced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2175 entries, 0 to 2355
# Data columns (total 13 columns):
# tweet_id                 2175 non-null int64
# in_reply_to_status_id    78 non-null float64
# in_reply_to_user_id      78 non-null float64
# timestamp                2175 non-null object
# source                   2175 non-null object
# text                     2175 non-null object
# expanded_urls            2117 non-null object
# rating_10_scale          2175 non-null object
# dog_name                 2172 non-null object
# doggo                    2175 non-null object
# floofer                  2175 non-null object
# pupper                   2175 non-null object
# puppo                    2175 non-null object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 237.9+ KB

# %%
df_enhanced.timestamp = pd.to_datetime(df_enhanced.timestamp)

# %%
df_enhanced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2175 entries, 0 to 2355
# Data columns (total 13 columns):
# tweet_id                 2175 non-null int64
# in_reply_to_status_id    78 non-null float64
# in_reply_to_user_id      78 non-null float64
# timestamp                2175 non-null datetime64[ns]
# source                   2175 non-null object
# text                     2175 non-null object
# expanded_urls            2117 non-null object
# rating_10_scale          2175 non-null object
# dog_name                 2172 non-null object
# doggo                    2175 non-null object
# floofer                  2175 non-null object
# pupper                   2175 non-null object
# puppo                    2175 non-null object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(9)
# memory usage: 237.9+ KB

# %% [markdown]
# Lambda and map function to convert floats in scientific format to simple string format in case of in_reply_to_status_id and in_reply_to_user_id.

# %%
df_enhanced['in_reply_to_status_id'] = df_enhanced.in_reply_to_status_id.map(lambda x: '{:.0f}'.format(x))
df_enhanced['in_reply_to_user_id'] = df_enhanced.in_reply_to_user_id.map(lambda x: '{:.0f}'.format(x))

# %% [markdown]
# #### Test:
#
# All the values not havving null.

# %%
df_enhanced[df_enhanced['in_reply_to_status_id'] != 'nan']
# Out:
#                 tweet_id in_reply_to_status_id in_reply_to_user_id  \
# 30    886267009285017600    886266357075128320          2281181600
# 55    881633300179243008    881607037314052096            47384430
# 64    879674319642796034    879553827334172672          3105440746
# 113   870726314365509632    870726202742493184            16487760
# 148   863427515083354112    863425645568774144            77596200
# 149   863079547188785154    667152164079423488          4196983835
# 179   857214891891077121    857156678055342080           180670967
# 184   856526610513747968    855818117272018944          4196983835
# 186   856288084350160898    856286004109553664           279280991
# 188   855862651834028034    855861584463351808           194351775
# 189   855860136149123072    855858535607001088            13615722
# 218   850333567704068097    850328818778820608            21955058
# 228   848213670039564288    848212111729840128          4196983835
# ...

# %% [markdown]
# #### Define:
#
# Unecessary category columns:  doggo, floofer, pupper, puppo
#
# #### Code:
#
# All the dog stage columns are merged into one single columns.

# %%
columns_melt = df_enhanced.loc[ :, 'doggo' : 'puppo']
columns_remain = df_enhanced.loc[:, 'tweet_id': 'dog_name']

df_enhanced = pd.melt(df_enhanced, id_vars = columns_remain, value_vars = columns_melt, 
                         var_name = 'stages', value_name = 'dog_stage')

# %%
df_enhanced = df_enhanced.drop('stages', axis = 1)

# %% [markdown]
# There are so many redundancy data.

# %%
df_enhanced.duplicated(subset = "tweet_id").sum()
# Out:
# 6525

# %% [markdown]
# It has to sort out and delete all duplicate values but the last data in reman same because first is already removed.

# %%
df_enhanced = df_enhanced.sort_values('dog_stage').drop_duplicates('tweet_id', keep = 'last')

# %% [markdown]
# #### Test:
#
# See the length and count the redundancy data by id.

# %%
len(df_enhanced)
# Out:
# 2175

# %%
df_enhanced.duplicated(subset = "tweet_id").sum()
# Out:
# 0

# %% [markdown]
# #### Define:
# Source column is not readable
#
# #### Code:
#
# A new user_source column is created which is based on the source values. The unnecessary long source column is removed.

# %%
print(df_enhanced['source'])
# Out:
# 2095    <a href="http://twitter.com/download/iphone" r...
# 2094    <a href="http://twitter.com" rel="nofollow">Tw...
# 2093    <a href="http://twitter.com" rel="nofollow">Tw...
# 2092    <a href="http://twitter.com" rel="nofollow">Tw...
# 2091    <a href="http://twitter.com" rel="nofollow">Tw...
# 2090    <a href="http://twitter.com" rel="nofollow">Tw...
# 2089    <a href="http://twitter.com" rel="nofollow">Tw...
# 2088    <a href="http://twitter.com" rel="nofollow">Tw...
# 2087    <a href="http://twitter.com" rel="nofollow">Tw...
# 2086    <a href="http://twitter.com" rel="nofollow">Tw...
# 2085    <a href="http://twitter.com" rel="nofollow">Tw...
# 2084    <a href="http://twitter.com" rel="nofollow">Tw...
# 2083    <a href="http://twitter.com" rel="nofollow">Tw...
# 2082    <a href="http://twitter.com" rel="nofollow">Tw...
# 2096    <a href="http://twitter.com/download/iphone" r...
# 2081    <a href="http://twitter.com" rel="nofollow">Tw...
# ...

# %% [markdown]
# Extracting the source column.

# %%
source = df_enhanced['source']

user_source = []

for item in df_enhanced['source']:
    if item.__contains__("Twitter for iPhone"):
        user_source.append("Twitter for iPhone")
    elif item.__contains__("Twitter Web Client"):
        user_source.append("Twitter Web Client")
    elif item.__contains__('Vine - Make a Scene'):
        user_source.append("Vine")
    elif item.__contains__('TweetDeck'):
        user_source.append("TweetDeck")

# %% [markdown]
# Doublecheck if we could capture all the values. The output should be True.

# %%
len(user_source) == len(df_enhanced['source'])
# Out:
# True

# %% [markdown]
# Add the new list to the df_enhanced dataset.

# %%
df_enhanced['user_source'] = user_source

# %% [markdown]
# #### Test:

# %%
df_enhanced['user_source'].head(15)
# Out:
# 2095    Twitter for iPhone
# 2094    Twitter Web Client
# 2093    Twitter Web Client
# 2092    Twitter Web Client
# 2091    Twitter Web Client
# 2090    Twitter Web Client
# 2089    Twitter Web Client
# 2088    Twitter Web Client
# 2087    Twitter Web Client
# 2086    Twitter Web Client
# 2085    Twitter Web Client
# 2084    Twitter Web Client
# 2083    Twitter Web Client
# 2082    Twitter Web Client
# 2096    Twitter for iPhone
# Name: user_source, dtype: object

# %% [markdown]
# Drop the unecessary source column.

# %%
df_enhanced = df_enhanced.drop(['source'], axis = 1)

# %% [markdown]
# Change the datatype from string to categorical - user_source column.

# %%
df_enhanced['user_source'] = df_enhanced.user_source.astype('category')

# %%
df_enhanced.head(3)
# Out:
#                 tweet_id in_reply_to_status_id in_reply_to_user_id  \
# 2095  667443425659232256                   nan                 nan
# 2094  667453023279554560                   nan                 nan
# 2093  667455448082227200                   nan                 nan
#
#                timestamp                                               text  \
# 2095 2015-11-19 20:44:47  Exotic dog here. Long neck. Weird paws. Obsess...
# 2094 2015-11-19 21:22:56  Meet Cupcake. I would do unspeakable things fo...
# 2093 2015-11-19 21:32:34  This is Reese and Twips. Reese protects Twips....
#
#                                           expanded_urls rating_10_scale  \
# 2095  https://twitter.com/dog_rates/status/667443425...               6
# 2094  https://twitter.com/dog_rates/status/667453023...              11
# 2093  https://twitter.com/dog_rates/status/667455448...               7
#
#      dog_name dog_stage         user_source
# 2095      NaN      None  Twitter for iPhone
# ...

# %% [markdown]
# #### Define:
#
# There are 3 dataset instead of 1 master dataset
#
# #### Code:
#
# I merged the df_enhanced and df_tweets dataframe together by id values, using left join.

# %%
df_clean = pd.merge(left=df_enhanced,right=df_tweets, left_on='tweet_id', right_on='id', how = 'left')

# %% [markdown]
# Drop the unecessary id and retweeted columns.

# %%
df_clean = df_clean.drop(['id', 'retweeted'], axis = 1)

# %% [markdown]
# ### Cleaning 2: df_breed dataset

# %% [markdown]
# #### Define:
#  Non-dog records in the dataset (eg.: shopping cart, box turtle...)
#
# #### Code:
# I observed that there are a lot of other things in the dataset, identified as dog by the neural network. As the predicitions was not always consistent and a lot of dog pictures was identified something else, too, I only dropped the rows, where none of the three predictions was identified as dogs. With this method, I could exclude as many incorrect data as possible and keep many good data as well.

# %%
df_breed.query('p1_dog == False and p2_dog == False and p3_dog == False')
# Out:
#                 tweet_id                                            jpg_url  \
# 6     666051853826850816    https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 17    666104133288665088    https://pbs.twimg.com/media/CT56LSZWoAAlJj2.jpg
# 18    666268910803644416    https://pbs.twimg.com/media/CT8QCd1WEAADXws.jpg
# 21    666293911632134144    https://pbs.twimg.com/media/CT8mx7KW4AEQu8N.jpg
# 25    666362758909284353    https://pbs.twimg.com/media/CT9lXGsUcAAyUFt.jpg
# 29    666411507551481857    https://pbs.twimg.com/media/CT-RugiWIAELEaq.jpg
# 45    666786068205871104    https://pbs.twimg.com/media/CUDmZIkWcAAIPPe.jpg
# 50    666837028449972224    https://pbs.twimg.com/media/CUEUva1WsAA2jPb.jpg
# 51    666983947667116034    https://pbs.twimg.com/media/CUGaXDhW4AY9JUH.jpg
# 53    667012601033924608    https://pbs.twimg.com/media/CUG0bC0U8AAw2su.jpg
# 56    667065535570550784    https://pbs.twimg.com/media/CUHkkJpXIAA2w3n.jpg
# ...

# %%
df_breed = df_breed.query('p1_dog == True or p2_dog == True or p3_dog == True')

# %% [markdown]
# #### Test:

# %%
df_breed.query('p1_dog == False and p2_dog == False and p3_dog == False')
# Out:
# Empty DataFrame
# Columns: [tweet_id, jpg_url, img_num, p1, p1_conf, p1_dog, p2, p2_conf, p2_dog, p3, p3_conf, p3_dog]
# Index: []

# %%
df_breed.columns
# Out:
# Index(['tweet_id', 'jpg_url', 'img_num', 'p1', 'p1_conf', 'p1_dog', 'p2',
#        'p2_conf', 'p2_dog', 'p3', 'p3_conf', 'p3_dog'],
#       dtype='object')

# %%
df_breed.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %% [markdown]
# #### Define:
# Dog breeds start with lower case letters and contain _ characters
#
# #### Code:
# I changed the first letter of the dog breeds from lower case letters to upper case letters and with remove() function I removed the _ characters to make the form consistent and clean.

# %%
df_breed['p1'] = df_breed.p1.str.capitalize()
df_breed['p2'] = df_breed.p1.str.capitalize()
df_breed['p3'] = df_breed.p1.str.capitalize()

# %%
df_breed['p1'].replace(regex=True,inplace=True,to_replace="_",value=r' ')
df_breed['p2'].replace(regex=True,inplace=True,to_replace="_",value=r' ')
df_breed['p3'].replace(regex=True,inplace=True,to_replace="_",value=r' ')

# %% [markdown]
# #### Test:

# %%
df_breed.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                      p2  \
# 0        1  Welsh springer spaniel  0.465074    True  Welsh springer spaniel
# 1        1                 Redbone  0.506826    True                 Redbone
# 2        1         German shepherd  0.596461    True         German shepherd
# 3        1     Rhodesian ridgeback  0.408143    True     Rhodesian ridgeback
# 4        1      Miniature pinscher  0.560311    True      Miniature pinscher
#
#     p2_conf  p2_dog                      p3   p3_conf  p3_dog
# ...

# %% [markdown]
# #### Define:
# There are 3 dataset instead of 1 master dataset
#
# #### Code:
#
# Merging df_breed dataset with the df_clean dataset using left join to create one final dataset.

# %%
df_master = pd.merge(left=df_clean,right=df_breed, left_on='tweet_id', right_on='tweet_id', how = 'left')

# %% [markdown]
# #### Test:
# Doublechecking the results.

# %%
df_master.head()
# Out:
#              tweet_id in_reply_to_status_id in_reply_to_user_id  \
# 0  667443425659232256                   nan                 nan
# 1  667453023279554560                   nan                 nan
# 2  667455448082227200                   nan                 nan
# 3  667470559035432960                   nan                 nan
# 4  667491009379606528                   nan                 nan
#
#             timestamp                                               text  \
# 0 2015-11-19 20:44:47  Exotic dog here. Long neck. Weird paws. Obsess...
# 1 2015-11-19 21:22:56  Meet Cupcake. I would do unspeakable things fo...
# 2 2015-11-19 21:32:34  This is Reese and Twips. Reese protects Twips....
# 3 2015-11-19 22:32:36  This is a northern Wahoo named Kohl. He runs t...
# 4 2015-11-19 23:53:52  Two dogs in this one. Both are rare Jujitsu Py...
#
#                                        expanded_urls rating_10_scale dog_name  \
# ...

# %% [markdown]
# #### Define:
# The p1, p2, p2 columns should be categorical datatypes
#
# #### Code:
# To make better analyzis, I decided to changing some datatypes to categorical in the master dataset.

# %%
df_master.dog_name = df_master.dog_name.astype('category');
df_master.dog_stage = df_master.dog_stage.astype('category');
df_master ['p1'] = df_master.p1.astype('category');
df_master ['p2'] = df_master.p2.astype('category');
df_master ['p3'] = df_master.p3.astype('category');

# %% [markdown]
# ### Test:

# %%
df_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2175 entries, 0 to 2174
# Data columns (total 23 columns):
# tweet_id                 2175 non-null int64
# in_reply_to_status_id    2175 non-null object
# in_reply_to_user_id      2175 non-null object
# timestamp                2175 non-null datetime64[ns]
# text                     2175 non-null object
# expanded_urls            2117 non-null object
# rating_10_scale          2175 non-null object
# dog_name                 2172 non-null category
# dog_stage                2175 non-null category
# user_source              2175 non-null category
# favorite_count           2175 non-null int64
# retweet_count            2175 non-null int64
# jpg_url                  1686 non-null object
# img_num                  1686 non-null float64
# p1                       1686 non-null category
# p1_conf                  1686 non-null float64
# p1_dog                   1686 non-null object
# p2                       1686 non-null category
# ...

# %% [markdown]
# I saved the dataset as a csv file.

# %%
df_master.to_csv('twitter_archive_master.csv')
